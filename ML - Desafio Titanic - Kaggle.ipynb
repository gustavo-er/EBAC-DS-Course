# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# Leitura dos dados:

# %%
train_data = pd.read_csv("/kaggle/input/titanic/train.csv")
train_data.head(n=10)

# %%
test_data = pd.read_csv("/kaggle/input/titanic/test.csv")
test_data.head()

# %% [markdown]
# * Calculando a porcentagem de homens e mulheres que sobreviveram:

# %%
female = train_data.loc[train_data.Sex == 'female']['Survived']
rate_women = round((sum(female)/len(female))*100, 2)
print(f'{rate_women} % mulheres sobreviveram')

# %%
male = train_data.loc[train_data.Sex =='male']['Survived']
rate_men = round((sum(male)/len(male))*100, 2)
print(f'{rate_men} % de homens sobreviveram')

# %% [markdown]
# Conforme as observações, podemos concluir que a maioria dos passageiros sobreviventes eram mulheres. Baseado nestes fatos, iremos construir um modelo de ML para precisar com maior exatidão estes fatos.

# %% [markdown]
# # Machine Learning - Explorando os dados #

# %%
from sklearn.ensemble import RandomForestClassifier

y = train_data['Survived']

features = ['Pclass', 'Sex', 'SibSp', 'Parch']
X = pd.get_dummies(train_data[features])
X_test = pd.get_dummies(test_data[features])

model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X, y)
predictions = model.predict(X_test)

output = pd.DataFrame({'PassengerId': test_data.PassengerId, 'Survived': predictions})
output.to_csv('submission.csv', index=False)
print("Salvo!")
